# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]

dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','friedman_mse','absolute_error'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)

grid_predictions = grid.predict(X_test)

# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8698306029087625

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.097744      0.003653         0.011217    9.510161e-04
# 1        0.788549      0.026192         0.033981    2.189774e-03
# 2        0.088083      0.005050         0.011660    1.976192e-03
# 3        0.765162      0.015465         0.034981    3.031012e-03
# 4        0.083352      0.002415         0.010994    1.548927e-03
# 5        0.780154      0.031979         0.034980    3.223383e-03
# 6        0.097344      0.009260         0.013793    2.784209e-03
# 7        0.762363      0.016512         0.034381    3.005059e-03
# 8        0.201285      0.010569         0.010994    1.413875e-03
# 9        1.932094      0.035298         0.033581    2.869292e-03
# 10       0.195088      0.008630         0.008995    4.768372e-07
# 11       1.678839      0.260732         0.026785    5.737734e-03
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4     friedman_mse               sqrt                 10
# 5     friedman_mse               sqrt                100
# 6     friedman_mse               log2                 10
# 7     friedman_mse               log2                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.833446
# 1   {'criterion': 'squared_error', 'max_features':...           0.870605
# 2   {'criterion': 'squared_error', 'max_features':...           0.841431
# 3   {'criterion': 'squared_error', 'max_features':...           0.867324
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.840702
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.863900
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.844607
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.865445
# 8   {'criterion': 'absolute_error', 'max_features'...           0.839822
# 9   {'criterion': 'absolute_error', 'max_features'...           0.862070
# 10  {'criterion': 'absolute_error', 'max_features'...           0.843273
# 11  {'criterion': 'absolute_error', 'max_features'...           0.856975
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.753537           0.789793           0.798548
# 1            0.792666           0.810006           0.830643
# 2            0.782129           0.785900           0.815692
# 3            0.799470           0.804749           0.829886
# 4            0.776240           0.808389           0.789106
# 5            0.790047           0.807400           0.829083
# 6            0.770492           0.758727           0.803349
# 7            0.790742           0.809867           0.824912
# 8            0.765657           0.797512           0.807027
# 9            0.796703           0.808756           0.824496
# 10           0.778061           0.789166           0.792561
# 11           0.795322           0.805872           0.824556
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.752604         0.785586        0.030303               11
# 1            0.767035         0.814191        0.035093                2
# 2            0.759859         0.797002        0.028451                7
# 3            0.770238         0.814333        0.032579                1
# 4            0.747441         0.792375        0.031248                8
# 5            0.767825         0.811651        0.032983                5
# 6            0.737864         0.783008        0.037396               12
# 7            0.772133         0.812620        0.031834                4
# 8            0.741617         0.790327        0.033946               10
# 9            0.773708         0.813147        0.029555                3
# 10           0.755167         0.791646        0.028940                9
# 11           0.767699         0.810085        0.029801                6
