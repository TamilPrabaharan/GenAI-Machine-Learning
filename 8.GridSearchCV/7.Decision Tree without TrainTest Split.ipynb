# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]

dependent = dataset[['charges']]

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['squared_error','friedman_mse','absolute_error'],
             'max_features':['sqrt','log2'],
             'splitter':['best','random']}
grid= GridSearchCV(DecisionTreeRegressor(), param_grid, refit= True, verbose=3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
import matplotlib.pyplot as plt
#from sklearn import tree
#tree.plot_tree(grid)
plt.show()

# %%
grid_predictions = grid.predict(independent)

# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}: 0.998667156135576

# %%
# print best parameter after tuning
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018971      0.001358         0.008973        0.000634
# 1        0.014791      0.000747         0.007996        0.001095
# 2        0.016990      0.001788         0.009195        0.001599
# 3        0.015791      0.004164         0.009195        0.001469
# 4        0.019242      0.003747         0.008542        0.001419
# 5        0.014192      0.001469         0.008067        0.001380
# 6        0.018389      0.002576         0.010594        0.003380
# 7        0.013792      0.002314         0.008395        0.002575
# 8        0.055967      0.010444         0.007595        0.001356
# 9        0.043375      0.003005         0.007396        0.001356
# 10       0.056567      0.003198         0.007396        0.001020
# 11       0.041176      0.001599         0.005597        0.000489
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.702097
# 1   {'criterion': 'squared_error', 'max_features':...           0.741054
# 2   {'criterion': 'squared_error', 'max_features':...           0.717008
# 3   {'criterion': 'squared_error', 'max_features':...           0.711710
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.684886
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.613471
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.709806
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.675845
# 8   {'criterion': 'absolute_error', 'max_features'...           0.644375
# 9   {'criterion': 'absolute_error', 'max_features'...           0.715849
# 10  {'criterion': 'absolute_error', 'max_features'...           0.738264
# 11  {'criterion': 'absolute_error', 'max_features'...           0.574083
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.600942           0.689711           0.732101
# 1            0.577544           0.725210           0.729717
# 2            0.590299           0.675357           0.703441
# 3            0.605737           0.716239           0.598465
# 4            0.636803           0.562184           0.719823
# 5            0.536072           0.724056           0.657401
# 6            0.690807           0.752160           0.642070
# 7            0.592471           0.710145           0.697207
# 8            0.588563           0.698630           0.729443
# 9            0.665080           0.607360           0.688608
# 10           0.580335           0.669616           0.711192
# 11           0.650319           0.683156           0.588925
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.688315         0.682633        0.043776                4
# 1            0.699639         0.694633        0.060093                2
# 2            0.719534         0.681128        0.048049                5
# 3            0.517388         0.629908        0.075337               11
# 4            0.722282         0.665196        0.060080                7
# 5            0.715463         0.649293        0.069478               10
# 6            0.730148         0.704998        0.037526                1
# 7            0.626161         0.660366        0.044395                8
# 8            0.706954         0.673593        0.050878                6
# 9            0.615287         0.658437        0.041765                9
# 10           0.714945         0.682870        0.055836                3
# 11           0.627623         0.624821        0.039809               12

# %%
import pickle
filename="finalized_model_DecisionTree_GridSearchCV_insurance.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 28
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]]) #change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[5116.5004]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
