# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]

dependent = dataset[['charges']]

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','friedman_mse','absolute_error'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
grid_predictions = grid.predict(independent)

# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}: 0.9769364614187351

# %%
# print best parameter after tuning
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.107737      0.004532         0.012193        0.000748
# 1        0.926070      0.027491         0.040177        0.004164
# 2        0.105940      0.006353         0.013848        0.003082
# 3        0.913677      0.022163         0.037579        0.002415
# 4        0.101342      0.005533         0.010594        0.000800
# 5        0.912878      0.022174         0.040377        0.005273
# 6        0.100942      0.006096         0.011793        0.002134
# 7        0.902883      0.021644         0.047573        0.004584
# 8        0.310821      0.021621         0.010595        0.000489
# 9        2.819881      0.047543         0.033287        0.000749
# 10       0.289504      0.016280         0.010338        0.000398
# 11       2.547344      0.356787         0.029982        0.005997
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4     friedman_mse               sqrt                 10
# 5     friedman_mse               sqrt                100
# 6     friedman_mse               log2                 10
# 7     friedman_mse               log2                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.844634
# 1   {'criterion': 'squared_error', 'max_features':...           0.859665
# 2   {'criterion': 'squared_error', 'max_features':...           0.827506
# 3   {'criterion': 'squared_error', 'max_features':...           0.856086
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.844857
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.859927
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.835296
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.856483
# 8   {'criterion': 'absolute_error', 'max_features'...           0.830938
# 9   {'criterion': 'absolute_error', 'max_features'...           0.858070
# 10  {'criterion': 'absolute_error', 'max_features'...           0.855928
# 11  {'criterion': 'absolute_error', 'max_features'...           0.862390
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.763793           0.848045           0.826417
# 1            0.778222           0.860140           0.830092
# 2            0.775180           0.852944           0.810957
# 3            0.779492           0.864042           0.830132
# 4            0.771818           0.843840           0.803422
# 5            0.778396           0.861340           0.830019
# 6            0.772951           0.852292           0.819634
# 7            0.779821           0.855876           0.828453
# 8            0.763528           0.851349           0.818092
# 9            0.779843           0.855630           0.828299
# 10           0.760098           0.811213           0.823247
# 11           0.783099           0.852650           0.826748
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.827466         0.822071        0.030424                8
# 1            0.842796         0.834183        0.030152                2
# 2            0.816357         0.816589        0.025248               11
# 3            0.842241         0.834399        0.029811                1
# 4            0.822988         0.817385        0.027413               10
# 5            0.840878         0.834112        0.030248                3
# 6            0.833765         0.822788        0.026986                7
# 7            0.840218         0.832170        0.028186                6
# 8            0.831507         0.819083        0.029743                9
# 9            0.843465         0.833061        0.028628                5
# 10           0.828899         0.815877        0.031499               12
# 11           0.843741         0.833726        0.027899                4
