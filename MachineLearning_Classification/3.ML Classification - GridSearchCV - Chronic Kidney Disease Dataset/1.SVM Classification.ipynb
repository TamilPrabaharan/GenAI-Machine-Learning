# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
               'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
               'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
               'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset["classification_yes"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
indep = sc.fit_transform(indep)

# %%
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV
param_grid= {'kernel':['linear','rbf','sigmoid'],
             'C':[10,100,1000,2000,3000], 'gamma':['auto','scale']}

grid= GridSearchCV(SVC(probability=True), param_grid, refit= True, verbose=3, cv=5, n_jobs=-1, scoring='f1_weighted')

grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.022587      0.004407         0.009595        0.002153      10
# 1        0.023187      0.004576         0.014192        0.008992      10
# 2        0.023187      0.005703         0.009595        0.001853      10
# 3        0.019388      0.001199         0.007796        0.002134      10
# 4        0.022586      0.003439         0.010394        0.003260      10
# 5        0.019188      0.002711         0.011794        0.005773      10
# 6        0.018789      0.002923         0.007995        0.000632     100
# 7        0.019188      0.002924         0.010794        0.002480     100
# 8        0.021388      0.002726         0.008994        0.003097     100
# 9        0.017390      0.001854         0.009394        0.001496     100
# 10       0.020940      0.003846         0.011395        0.004360     100
# 11       0.019385      0.004924         0.007607        0.000499     100
# 12       0.015790      0.002313         0.009594        0.004270    1000
# 13       0.017191      0.000748         0.008395        0.000489    1000
# 14       0.017388      0.000488         0.007595        0.000489    1000
# 15       0.017590      0.001355         0.007796        0.000748    1000
# 16       0.018104      0.002423         0.008595        0.001019    1000
# 17       0.016991      0.002098         0.008794        0.002225    1000
# 18       0.016390      0.001356         0.008395        0.001019    2000
# 19       0.018988      0.003031         0.009195        0.000748    2000
# 20       0.018191      0.002037         0.008593        0.000797    2000
# 21       0.018189      0.002784         0.007995        0.000895    2000
# 22       0.018991      0.002451         0.009592        0.002727    2000
# 23       0.021188      0.003967         0.007598        0.000492    2000
# 24       0.016591      0.002574         0.008994        0.001548    3000
# 25       0.018190      0.002312         0.008192        0.000984    3000
# 26       0.016792      0.001936         0.008193        0.001168    3000
# 27       0.020588      0.003771         0.008595        0.001356    3000
# 28       0.020188      0.003308         0.009594        0.001356    3000
# 29       0.018790      0.001936         0.007994        0.001551    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto      sigmoid
# 3        scale       linear
# 4        scale          rbf
# 5        scale      sigmoid
# 6         auto       linear
# 7         auto          rbf
# 8         auto      sigmoid
# 9        scale       linear
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto          rbf
# 14        auto      sigmoid
# 15       scale       linear
# 16       scale          rbf
# 17       scale      sigmoid
# 18        auto       linear
# 19        auto          rbf
# 20        auto      sigmoid
# 21       scale       linear
# 22       scale          rbf
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto      sigmoid
# 27       scale       linear
# 28       scale          rbf
# 29       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.802005
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.926015
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.913778
# 3     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.802005
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.926015
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.913778
# 6     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.802005
# 7        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.913778
# 8    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.814706
# 9    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.802005
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.913778
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.814706
# 12   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.802005
# 13      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.913778
# 14  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.814706
# 15  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.802005
# 16     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.913778
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.814706
# 18   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.802005
# 19      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.913778
# 20  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.814706
# 21  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.802005
# 22     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.913778
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.814706
# 24   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.802005
# 25      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.913778
# 26  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.814706
# 27  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.802005
# 28     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.913778
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.814706
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.975000           0.987539           1.000000
# 1            0.987539           1.000000           1.000000
# 2            0.987539           1.000000           1.000000
# 3            0.975000           0.987539           1.000000
# 4            0.987539           1.000000           1.000000
# 5            0.987539           1.000000           1.000000
# 6            0.975000           0.987539           1.000000
# 7            0.987539           1.000000           1.000000
# 8            0.975000           1.000000           0.987539
# 9            0.975000           0.987539           1.000000
# 10           0.987539           1.000000           1.000000
# 11           0.975000           1.000000           0.987539
# 12           0.975000           0.987539           1.000000
# 13           0.987539           1.000000           1.000000
# 14           0.975000           0.987539           0.987539
# 15           0.975000           0.987539           1.000000
# 16           0.987539           1.000000           1.000000
# 17           0.975000           0.987539           0.987539
# 18           0.975000           0.987539           1.000000
# 19           0.987539           1.000000           1.000000
# 20           0.975000           0.987539           0.987539
# 21           0.975000           0.987539           1.000000
# 22           0.987539           1.000000           1.000000
# 23           0.975000           0.987539           0.987539
# 24           0.975000           0.987539           1.000000
# 25           0.987539           1.000000           1.000000
# 26           0.975000           0.987539           0.987539
# 27           0.975000           0.987539           1.000000
# 28           0.987539           1.000000           1.000000
# 29           0.975000           0.987539           0.987539
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.987298         0.950369        0.074602               21
# 1            0.987298         0.980171        0.027656                1
# 2            0.987298         0.977723        0.032464                3
# 3            0.987298         0.950369        0.074602               21
# 4            0.987298         0.980171        0.027656                1
# 5            0.987298         0.977723        0.032464                3
# 6            0.987298         0.950369        0.074602               21
# 7            0.987298         0.977723        0.032464                3
# 8            0.974684         0.950386        0.068480               19
# 9            0.987298         0.950369        0.074602               21
# 10           0.987298         0.977723        0.032464                3
# 11           0.974684         0.950386        0.068480               19
# 12           0.987298         0.950369        0.074602               21
# 13           0.987298         0.977723        0.032464                3
# 14           1.000000         0.952957        0.069576               13
# 15           0.987298         0.950369        0.074602               21
# 16           0.987298         0.977723        0.032464                3
# 17           1.000000         0.952957        0.069576               13
# 18           0.987298         0.950369        0.074602               21
# 19           0.987298         0.977723        0.032464                3
# 20           1.000000         0.952957        0.069576               13
# 21           0.987298         0.950369        0.074602               21
# 22           0.987298         0.977723        0.032464                3
# 23           1.000000         0.952957        0.069576               13
# 24           0.987298         0.950369        0.074602               21
# 25           0.987298         0.977723        0.032464                3
# 26           1.000000         0.952957        0.069576               13
# 27           0.987298         0.950369        0.074602               21
# 28           0.987298         0.977723        0.032464                3
# 29           1.000000         0.952957        0.069576               13

# %%
grid_predictions = grid.predict(indep)

# %%
print("Best parameters found: ", grid.best_params_)
#print("Best accuracy score: ", grid.best_score_)
# Out:
# Best parameters found:  {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(dep, grid_predictions)

# %%
print(cm)
# Out:
# [[150   0]
#  [  0 249]]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(dep, grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       150
#            1       1.00      1.00      1.00       249
#
#     accuracy                           1.00       399
#    macro avg       1.00      1.00      1.00       399
# weighted avg       1.00      1.00      1.00       399

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(dep,grid.predict_proba(indep)[:,1])
# Out:
# 1.0
